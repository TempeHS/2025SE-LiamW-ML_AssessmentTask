# %% [markdown]
# # Model Training - Linear Regression

# %% [markdown]
# Linear Regression is a ML algorithms that provides linear relationships between features and targets to predict outcomes of future data. This will be used to predict the Global_Sales of a product from other features.

# %% [markdown]
# Loading Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# #### Multi_Variate Linear Regression

# %% [markdown]
# storing the data columns for the linear regression algorithm

# %%
# Create a data frame from the csv file
training_data = pd.read_csv('training_data.csv')

x_name = ['popularity','Year','Genre_Action','Genre_Adventure','Genre_Fighting','Genre_Misc','Genre_Platform','Genre_Puzzle','Genre_Racing','Genre_Role-Playing','Genre_Shooter','Genre_Simulation','Genre_Sports','Genre_Strategy']
y_name = 'Global_Sales'
x = np.array(training_data[x_name])
y = np.array(training_data[y_name])

# %% [markdown]
# Plotting x and y using columns headings as graph labels

# %%
fig,ax=plt.subplots(1,len(x_name),figsize=(20,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'target')
    ax[i].set_xlabel(x_name[i])
ax[0].set_ylabel("Target"); ax[0].legend();
fig.suptitle("Diabetes Disease Progress")
plt.show()

# %% [markdown]
# Using Sci-Kit library to instantiate a ML model class and fitting the model to data

# %%
my_model = LinearRegression()
my_model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# Plotting the features, target and Multi-Variate Linear Regression model

# %%
y_pred = my_model.predict(x)
fig,ax=plt.subplots(1,len(x_name),figsize=(12,3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x[:,i],y, label = 'target')
    ax[i].set_xlabel(x_name[i])
    ax[i].scatter(x[:,i],y_pred,color="orange", label = 'predict')
ax[0].set_ylabel("Target"); ax[0].legend();
fig.suptitle("Diabetes Disease Progress")
plt.show()

# %%
filename = 'my_saved_model1.sav'
pickle.dump(my_model, open('../4.Model_Testing_and_Validation/' + filename, 'wb'))
